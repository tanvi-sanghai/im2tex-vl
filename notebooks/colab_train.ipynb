# %%
# !pip install -q unsloth

# %%
# !git clone https://github.com/<your-username>/qwen2vl-latex-ocr.git
# %cd qwen2vl-latex-ocr

# %%
# !pip install -q -r requirements.txt

# %%
# !python -m src.train

# %%
# !python -m src.evaluate

# %%
# !zip -r qwen2vl_lora_adapter.zip checkpoints/
from google.colab import files
files.download("qwen2vl_lora_adapter.zip")
files.download("results/comparisons.md")
